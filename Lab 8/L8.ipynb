# %% [markdown]
# ## Scenario 1

# %%
# %pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\users\jayas\miniconda3\lib\site-packages (0.24.0)
# Requirement already satisfied: scipy>=1.16.3 in c:\users\jayas\miniconda3\lib\site-packages (from mlxtend) (1.17.1)
# Requirement already satisfied: numpy>=2.3.5 in c:\users\jayas\miniconda3\lib\site-packages (from mlxtend) (2.4.4)
# Requirement already satisfied: pandas>=2.3.3 in c:\users\jayas\miniconda3\lib\site-packages (from mlxtend) (2.3.3)
# Requirement already satisfied: scikit-learn>=1.8.0 in c:\users\jayas\miniconda3\lib\site-packages (from mlxtend) (1.8.0)
# Requirement already satisfied: matplotlib>=3.10.8 in c:\users\jayas\miniconda3\lib\site-packages (from mlxtend) (3.10.8)
# Requirement already satisfied: joblib>=1.5.2 in c:\users\jayas\miniconda3\lib\site-packages (from mlxtend) (1.5.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jayas\miniconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\jayas\miniconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jayas\miniconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jayas\miniconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\jayas\miniconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\jayas\miniconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (11.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\jayas\miniconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jayas\miniconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jayas\miniconda3\lib\site-packages (from pandas>=2.3.3->mlxtend) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jayas\miniconda3\lib\site-packages (from pandas>=2.3.3->mlxtend) (2025.2)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\jayas\miniconda3\lib\site-packages (from scikit-learn>=1.8.0->mlxtend) (3.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\jayas\miniconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt

from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# %%
df = pd.read_csv("Groceries_dataset.csv")

print(df.head())
# Out:
#    Member_number        Date   itemDescription
# 0           1808  21-07-2015    tropical fruit
# 1           2552  05-01-2015        whole milk
# 2           2300  19-09-2015         pip fruit
# 3           1187  12-12-2015  other vegetables
# 4           3037  01-02-2015        whole milk

# %%
# Convert dataset into list of transactions
transactions = df.groupby('Member_number')['itemDescription'].apply(list).values.tolist()

print(transactions[:5])
# Out:
# [['soda', 'canned beer', 'sausage', 'sausage', 'whole milk', 'whole milk', 'pickled vegetables', 'misc. beverages', 'semi-finished bread', 'hygiene articles', 'yogurt', 'pastry', 'salty snack'], ['frankfurter', 'frankfurter', 'beef', 'sausage', 'whole milk', 'soda', 'curd', 'white bread', 'whole milk', 'soda', 'whipped/sour cream', 'rolls/buns'], ['tropical fruit', 'butter milk', 'butter', 'frozen vegetables', 'sugar', 'specialty chocolate', 'whole milk', 'other vegetables'], ['sausage', 'root vegetables', 'rolls/buns', 'detergent', 'frozen meals', 'rolls/buns', 'dental care', 'rolls/buns'], ['other vegetables', 'pip fruit', 'root vegetables', 'canned beer', 'rolls/buns', 'whole milk', 'other vegetables', 'hygiene articles', 'whole milk', 'whole milk', 'frozen fish', 'red/blush wine', 'chocolate', 'shopping bags', 'dish cleaner', 'packaged fruit/vegetables', 'tropical fruit', 'rolls/buns', 'cling film/bags', 'chocolate', 'pastry']]

# %%
te = TransactionEncoder()
te_data = te.fit(transactions).transform(transactions)

df_encoded = pd.DataFrame(te_data, columns=te.columns_)

print(df_encoded.head())
# Out:
#    Instant food products  UHT-milk  abrasive cleaner  artif. sweetener  \
# 0                  False     False             False             False
# 1                  False     False             False             False
# 2                  False     False             False             False
# 3                  False     False             False             False
# 4                  False     False             False             False
#
#    baby cosmetics   bags  baking powder  bathroom cleaner   beef  berries  \
# 0           False  False          False             False  False    False
# 1           False  False          False             False   True    False
# 2           False  False          False             False  False    False
# 3           False  False          False             False  False    False
# 4           False  False          False             False  False    False
#
#    ...  turkey  vinegar  waffles  whipped/sour cream  whisky  white bread  \
# 0  ...   False    False    False               False   False        False
# 1  ...   False    False    False                True   False         True
# 2  ...   False    False    False               False   False        False
# 3  ...   False    False    False               False   False        False
# 4  ...   False    False    False               False   False        False
#
#    white wine  whole milk  yogurt  zwieback
# 0       False        True    True     False
# 1       False        True   False     False
# 2       False        True   False     False
# 3       False       False   False     False
# 4       False        True   False     False
#
# [5 rows x 167 columns]

# %%
frequent_itemsets = apriori(df_encoded, min_support=0.02, use_colnames=True)

print(frequent_itemsets.head())
# Out:
#     support         itemsets
# 0  0.078502       (UHT-milk)
# 1  0.031042  (baking powder)
# 2  0.119548           (beef)
# 3  0.079785        (berries)
# 4  0.062083      (beverages)

# %%
rules = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.3)

print(rules.head())
# Out:
#   antecedents         consequents  antecedent support  consequent support  \
# 0  (UHT-milk)  (other vegetables)            0.078502            0.376603
# 1  (UHT-milk)        (rolls/buns)            0.078502            0.349666
# 2  (UHT-milk)              (soda)            0.078502            0.313494
# 3  (UHT-milk)        (whole milk)            0.078502            0.458184
# 4      (beef)  (other vegetables)            0.119548            0.376603
#
#     support  confidence      lift  representativity  leverage  conviction  \
# 0  0.038994    0.496732  1.318979               1.0  0.009430    1.238697
# 1  0.031042    0.395425  1.130863               1.0  0.003592    1.075687
# 2  0.027450    0.349673  1.115406               1.0  0.002840    1.055632
# 3  0.040534    0.516340  1.126928               1.0  0.004565    1.120242
# 4  0.050795    0.424893  1.128223               1.0  0.005773    1.083966
#
#    zhangs_metric   jaccard  certainty  kulczynski
# 0       0.262440  0.093711   0.192700    0.300137
# 1       0.125578  0.078165   0.070361    0.242100
# 2       0.112280  0.075299   0.052700    0.218617
# 3       0.122227  0.081696   0.107336    0.302403
# 4       0.129082  0.114055   0.077462    0.279885

# %%
# Filter high-quality rules
strong_rules = rules[(rules['confidence'] > 0.5) & (rules['lift'] > 1)]

print(strong_rules[['antecedents', 'consequents', 'support', 'confidence', 'lift']])
# Out:
#                        antecedents   consequents   support  confidence  \
# 3                       (UHT-milk)  (whole milk)  0.040534    0.516340
# 7                           (beef)  (whole milk)  0.064135    0.536481
# 22                  (bottled beer)  (whole milk)  0.085428    0.537964
# 28                 (bottled water)  (whole milk)  0.112365    0.525810
# 33                   (brown bread)  (whole milk)  0.069779    0.513208
# ..                             ...           ...       ...         ...
# 856    (rolls/buns, soda, sausage)  (whole milk)  0.021036    0.585714
# 858    (soda, whole milk, sausage)  (rolls/buns)  0.021036    0.525641
# 860  (yogurt, rolls/buns, sausage)  (whole milk)  0.022832    0.640288
# 861  (yogurt, whole milk, sausage)  (rolls/buns)  0.022832    0.508571
# 865     (yogurt, rolls/buns, soda)  (whole milk)  0.024628    0.581818
#
#          lift
# 3    1.126928
# 7    1.170886
# 22   1.174124
# 28   1.147597
# 33   1.120091
# ..        ...
# 856  1.278339
# 858  1.503264
# 860  1.397448
# 861  1.454447
# 865  1.269836
#
# [244 rows x 5 columns]

# %%
# Top 10 frequent itemsets
top_items = frequent_itemsets.sort_values(by='support', ascending=False).head(10)

plt.figure()
plt.bar(range(len(top_items)), top_items['support'])
plt.xticks(range(len(top_items)), top_items['itemsets'], rotation=45)

plt.title("Top Frequent Itemsets")
plt.xlabel("Itemsets")
plt.ylabel("Support")

plt.show()

# %%
plt.figure()

plt.scatter(rules['support'], rules['confidence'])

plt.title("Support vs Confidence")
plt.xlabel("Support")
plt.ylabel("Confidence")

plt.show()

# %%
import networkx as nx

G = nx.DiGraph()

for _, row in strong_rules.iterrows():
    for a in row['antecedents']:
        for c in row['consequents']:
            G.add_edge(a, c, weight=row['lift'])

plt.figure(figsize=(20,15))
pos = nx.spring_layout(G)

nx.draw(G, pos, with_labels=True)

plt.title("Association Rules Network")
plt.show()

# %% [markdown]
# ## Scenario 2

# %% [markdown]
# ### Dimensioality reduction

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA

# %%
iris = load_iris()

X = iris.data
y = iris.target

feature_names = iris.feature_names

df = pd.DataFrame(X, columns=feature_names)

print(df.head())
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
print(df.isnull().sum())
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# dtype: int64

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
pca = PCA()

X_pca = pca.fit_transform(X_scaled)

# %%
explained_variance = pca.explained_variance_ratio_

print("Explained Variance Ratio:")
print(explained_variance)
# Out:
# Explained Variance Ratio:
# [0.72962445 0.22850762 0.03668922 0.00517871]

# %%
cumulative_variance = np.cumsum(explained_variance)

print("Cumulative Variance:")
print(cumulative_variance)
# Out:
# Cumulative Variance:
# [0.72962445 0.95813207 0.99482129 1.        ]

# %%
plt.figure()
plt.plot(range(1, len(explained_variance)+1), explained_variance, marker='o')

plt.title("Scree Plot")
plt.xlabel("Principal Components")
plt.ylabel("Explained Variance")

plt.show()

# %%
plt.figure()
plt.plot(range(1, len(cumulative_variance)+1), cumulative_variance, marker='o')

plt.title("Cumulative Variance")
plt.xlabel("Number of Components")
plt.ylabel("Cumulative Variance")

plt.show()

# %%
pca_2 = PCA(n_components=2)
X_reduced = pca_2.fit_transform(X_scaled)

# %%
plt.figure()

plt.scatter(X_reduced[:, 0], X_reduced[:, 1], c=y)

plt.title("PCA - 2D Projection")
plt.xlabel("Principal Component 1")
plt.ylabel("Principal Component 2")

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

pca_3 = PCA(n_components=3)
X_3d = pca_3.fit_transform(X_scaled)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(X_3d[:, 0], X_3d[:, 1], X_3d[:, 2], c=y)

ax.set_title("PCA - 3D Projection")

plt.show()
